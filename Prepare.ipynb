# %% [markdown]
# # Using your store items data:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sales_joined_df.csv',index_col=0)

# %%
df
# Out:
#         sale_amount                      sale_date  sale_id  \
# 0              13.0  Tue, 01 Jan 2013 00:00:00 GMT        1
# 1              11.0  Wed, 02 Jan 2013 00:00:00 GMT        2
# 2              14.0  Thu, 03 Jan 2013 00:00:00 GMT        3
# 3              13.0  Fri, 04 Jan 2013 00:00:00 GMT        4
# 4              10.0  Sat, 05 Jan 2013 00:00:00 GMT        5
# ...             ...                            ...      ...
# 365195         33.0  Wed, 27 Dec 2017 00:00:00 GMT   365196
# 365196         49.0  Thu, 28 Dec 2017 00:00:00 GMT   365197
# 365197         45.0  Fri, 29 Dec 2017 00:00:00 GMT   365198
# 365198         45.0  Sat, 30 Dec 2017 00:00:00 GMT   365199
# 365199         56.0  Sun, 31 Dec 2017 00:00:00 GMT   365200
#
#                  store_address   store_city  store_id store_state  \
# 0       12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 1       12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 2       12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 3       12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 4       12125 Alamo Ranch Pkwy  San Antonio         1          TX
# ...                        ...          ...       ...         ...
# 365195    8503 NW Military Hwy  San Antonio        10          TX
# 365196    8503 NW Military Hwy  San Antonio        10          TX
# 365197    8503 NW Military Hwy  San Antonio        10          TX
# 365198    8503 NW Military Hwy  San Antonio        10          TX
# 365199    8503 NW Military Hwy  San Antonio        10          TX
#
#         store_zipcode    item_brand  item_id                       item_name  \
# 0               78253      Riceland        1  Riceland American Jazmine Rice
# 1               78253      Riceland        1  Riceland American Jazmine Rice
# 2               78253      Riceland        1  Riceland American Jazmine Rice
# 3               78253      Riceland        1  Riceland American Jazmine Rice
# 4               78253      Riceland        1  Riceland American Jazmine Rice
# ...               ...           ...      ...                             ...
# 365195          78231  Usda Produce       20                     Plums Black
# 365196          78231  Usda Produce       20                     Plums Black
# 365197          78231  Usda Produce       20                     Plums Black
# 365198          78231  Usda Produce       20                     Plums Black
# 365199          78231  Usda Produce       20                     Plums Black
#
#         item_price    item_upc12    item_upc14
# 0             0.84   35200264013   35200264013
# 1             0.84   35200264013   35200264013
# 2             0.84   35200264013   35200264013
# 3             0.84   35200264013   35200264013
# 4             0.84   35200264013   35200264013
# ...            ...           ...           ...
# 365195        5.62  204040000000  204040000000
# 365196        5.62  204040000000  204040000000
# 365197        5.62  204040000000  204040000000
# 365198        5.62  204040000000  204040000000
# 365199        5.62  204040000000  204040000000
#
# [365200 rows x 14 columns]

# %% [markdown]
# ### 1. Convert date column to datetime format.

# %%
df.sale_date = pd.to_datetime(df.sale_date)

# %% [markdown]
# ### 2. Plot the distribution of sale_amount and item_price.

# %%
plt.scatter(y=df.sale_amount, x=df.item_price)
plt.title('Sale Amount vs. Item Price')
plt.xlabel('Item Price - Cost to Buy')
plt.ylabel('Sale Amount - Items Sold')
# Out:
# Text(0, 0.5, 'Sale Amount - Items Sold')

# %% [markdown]
# ### 3. Set the index to be the datetime variable.

# %%
df = df.set_index("sale_date").sort_index()

# %% [markdown]
# ### 4. Add a 'month' and 'day of week' column to your dataframe.

# %%
df['month'] = df.index.month

df['weekday'] = df.index.day_name()

df.head()
# Out:
#                            sale_amount  sale_id            store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0        1   12125 Alamo Ranch Pkwy
# 2013-01-01 00:00:00+00:00         14.0   118691       1015 S WW White Rd
# 2013-01-01 00:00:00+00:00         29.0   350593  2118 Fredericksburg Rdj
# 2013-01-01 00:00:00+00:00         21.0   116865          1520 Austin Hwy
# 2013-01-01 00:00:00+00:00         26.0   115039          516 S Flores St
#
#                             store_city  store_id store_state  store_zipcode  \
# sale_date
# 2013-01-01 00:00:00+00:00  San Antonio         1          TX          78253
# 2013-01-01 00:00:00+00:00  San Antonio         6          TX          78220
# 2013-01-01 00:00:00+00:00  San Antonio         3          TX          78201
# 2013-01-01 00:00:00+00:00  San Antonio         5          TX          78218
# 2013-01-01 00:00:00+00:00  San Antonio         4          TX          78204
#
#                                    item_brand  item_id  \
# sale_date
# 2013-01-01 00:00:00+00:00            Riceland        1
# 2013-01-01 00:00:00+00:00  Twinings Of London        7
# 2013-01-01 00:00:00+00:00        Usda Produce       20
# 2013-01-01 00:00:00+00:00  Twinings Of London        7
# 2013-01-01 00:00:00+00:00  Twinings Of London        7
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Twinings Of London Classics Lady Grey Tea - 20 Ct
# 2013-01-01 00:00:00+00:00                                        Plums Black
# 2013-01-01 00:00:00+00:00  Twinings Of London Classics Lady Grey Tea - 20 Ct
# 2013-01-01 00:00:00+00:00  Twinings Of London Classics Lady Grey Tea - 20 Ct
#
#                            item_price    item_upc12    item_upc14  month  \
# sale_date
# 2013-01-01 00:00:00+00:00        0.84   35200264013   35200264013      1
# 2013-01-01 00:00:00+00:00        9.64   70177154004   70177154004      1
# 2013-01-01 00:00:00+00:00        5.62  204040000000  204040000000      1
# 2013-01-01 00:00:00+00:00        9.64   70177154004   70177154004      1
# 2013-01-01 00:00:00+00:00        9.64   70177154004   70177154004      1
#
#                            weekday
# sale_date
# 2013-01-01 00:00:00+00:00  Tuesday
# 2013-01-01 00:00:00+00:00  Tuesday
# 2013-01-01 00:00:00+00:00  Tuesday
# 2013-01-01 00:00:00+00:00  Tuesday
# 2013-01-01 00:00:00+00:00  Tuesday

# %% [markdown]
# ### 5. Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
df['sales_total'] = df.sale_amount * df.item_price

# %% [markdown]
# ### 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
## very bottom cell

# %% [markdown]
# # Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:

# %%
import Acquire

# %%
ops_df = Acquire.get_open_power()

# %%
ops_df.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# ### 1. Convert date column to datetime format.

# %%
ops_df.Date = pd.to_datetime(ops_df.Date)

# %% [markdown]
# ### 2. Plot the distribution of each of your variables.

# %%
sns.pairplot(ops_df)

# %% [markdown]
# ### 3. Set the index to be the datetime variable.

# %%
ops_df = ops_df.set_index("Date").sort_index()

# %% [markdown]
# ### 4. Add a month and a year column to your dataframe.

# %%
ops_df['month'] = ops_df.index.month

ops_df['year'] = ops_df.index.year

ops_df.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  month  year
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN      1  2006
# 2006-01-02     1380.521   NaN    NaN         NaN      1  2006
# 2006-01-03     1442.533   NaN    NaN         NaN      1  2006
# 2006-01-04     1457.217   NaN    NaN         NaN      1  2006
# 2006-01-05     1477.131   NaN    NaN         NaN      1  2006

# %% [markdown]
# ### 5. Fill any missing values.

# %%
ops_df = ops_df.fillna(0)

# %%
ops_df.isnull().sum()
# Out:
# Consumption    0
# Wind           0
# Solar          0
# Wind+Solar     0
# month          0
# year           0
# dtype: int64

# %% [markdown]
# ### 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %%
def set_index(df, date_col):
    
    df['date_col'] = pd.to_datetime(df['date_col'])
    
    df = df.set_index('date_col').sort_index()
    
    return df

def visualize(df, x, y, title):
    
    plt.scatter(x=x, y=y)
    plt.title('title')
    plt.show()
    
    sns.pairplot(df)
    
def create_date_columns(df, date_types, date_col):
    '''
    'year','month','day','hour','week','weekday','weekday_name','quarter'
    create columns of these date types using date index or column
    '''
    
    # if date columns has already been set to index
    if date_col == 'index':
        for x in date_types:
            
            # will add the date column for every date type in the list
            if x == 'year':
                df['year'] = df.index.year
                
            if x == 'month':
                df['month'] = df.index.month
                
            if x == 'day':
                df['day'] = df.index.day
                
            if x == 'hour':
                df['hour'] = df.index.hour
                
            if x == 'week':
                df['week'] = df.index.week
                
            if x == 'weekday':
                df['weekday'] = df.index.weekday
                
            if x == 'weekday_name':
                df['weekday_name'] = df.index.day_name()
                
            if x == 'quarter':
                df['quarter'] = df.index.quarter
                
    # if date column has not yet been set to index
    else:
        for x in date_types:
            
            # will add the date column for every date type in the list
            if x == 'year':
                df['year'] = df[date_col].dt.year
                
            if x == 'month':
                df['month'] = df[date_col].dt.month
                
            if x == 'day':
                df['day'] = df[date_col].dt.day
                
            if x == 'hour':
                df['hour'] = df[date_col].dt.hour
                
            if x == 'week':
                df['week'] = df[date_col].dt.week
                
            if x == 'weekday':
                df['weekday'] = df[date_col].dt.weekday
                
            if x == 'weekday_name':
                df['weekday_name'] = df[date_col].dt.day_name()
                
            if x == 'quarter':
                df['quarter'] = df[date_col].dt.quarter
    
    return df
    
def sales_total():
    
    df['sales_total'] = df.sale_amount * df.item_price
    
    return df

# %%
create_date_columns(df, ['year','month','quarter'],'sale_date')
# Out:
#         sale_amount                 sale_date  sale_id  \
# 0              13.0 2013-01-01 00:00:00+00:00        1
# 1              11.0 2013-01-02 00:00:00+00:00        2
# 2              14.0 2013-01-03 00:00:00+00:00        3
# 3              13.0 2013-01-04 00:00:00+00:00        4
# 4              10.0 2013-01-05 00:00:00+00:00        5
# ...             ...                       ...      ...
# 365195         33.0 2017-12-27 00:00:00+00:00   365196
# 365196         49.0 2017-12-28 00:00:00+00:00   365197
# 365197         45.0 2017-12-29 00:00:00+00:00   365198
# 365198         45.0 2017-12-30 00:00:00+00:00   365199
# 365199         56.0 2017-12-31 00:00:00+00:00   365200
#
#                  store_address   store_city  store_id store_state  \
# 0       12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 1       12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 2       12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 3       12125 Alamo Ranch Pkwy  San Antonio         1          TX
# 4       12125 Alamo Ranch Pkwy  San Antonio         1          TX
# ...                        ...          ...       ...         ...
# 365195    8503 NW Military Hwy  San Antonio        10          TX
# 365196    8503 NW Military Hwy  San Antonio        10          TX
# 365197    8503 NW Military Hwy  San Antonio        10          TX
# 365198    8503 NW Military Hwy  San Antonio        10          TX
# 365199    8503 NW Military Hwy  San Antonio        10          TX
#
#         store_zipcode    item_brand  item_id                       item_name  \
# 0               78253      Riceland        1  Riceland American Jazmine Rice
# 1               78253      Riceland        1  Riceland American Jazmine Rice
# 2               78253      Riceland        1  Riceland American Jazmine Rice
# 3               78253      Riceland        1  Riceland American Jazmine Rice
# 4               78253      Riceland        1  Riceland American Jazmine Rice
# ...               ...           ...      ...                             ...
# 365195          78231  Usda Produce       20                     Plums Black
# 365196          78231  Usda Produce       20                     Plums Black
# 365197          78231  Usda Produce       20                     Plums Black
# 365198          78231  Usda Produce       20                     Plums Black
# 365199          78231  Usda Produce       20                     Plums Black
#
#         item_price    item_upc12    item_upc14  year  month  quarter
# 0             0.84   35200264013   35200264013  2013      1        1
# 1             0.84   35200264013   35200264013  2013      1        1
# 2             0.84   35200264013   35200264013  2013      1        1
# 3             0.84   35200264013   35200264013  2013      1        1
# 4             0.84   35200264013   35200264013  2013      1        1
# ...            ...           ...           ...   ...    ...      ...
# 365195        5.62  204040000000  204040000000  2017     12        4
# 365196        5.62  204040000000  204040000000  2017     12        4
# 365197        5.62  204040000000  204040000000  2017     12        4
# 365198        5.62  204040000000  204040000000  2017     12        4
# 365199        5.62  204040000000  204040000000  2017     12        4
#
# [365200 rows x 17 columns]
